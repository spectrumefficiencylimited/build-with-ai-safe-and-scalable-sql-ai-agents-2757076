# %%
x = "a"
y = "b"
print(x)
print(x,y)
print("This is variable x:", x)
print("This is variable x:", x, "and this is variable y:", y)
print("This is variable x:", x, and this is variable y:", y)
# Out:
#   Cell In[7], line 7
#     print("This is variable x:", x, and this is variable y:", y)
#                                                            ^
# SyntaxError: unterminated string literal (detected at line 7)
